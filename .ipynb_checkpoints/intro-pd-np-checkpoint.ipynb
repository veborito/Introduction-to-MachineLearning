# %%
import pandas as pd

# %%
X = pd.read_excel("./data/class.xlsx")
X
# Out:
#    Pseudonym  Height  Weight Gender  Age  Sporthours/week  \
# 0         CD  178.00      81      M   49                7
# 1         TB  180.00      75      M   22               16
# 2         BL  169.00      53      F   20                0
# 3         KG  183.00      80      M   25                1
# 4         TR  190.00      65      M   25                5
# 5         AR  178.00      82      M   21                4
# 6         BV  188.00      85      M   25                8
# 7         KG  178.00      65      M   24                2
# 8        Bob  179.00      69      M   23                2
# 9         DF  178.00      60      M   37                0
# 10        ZZ  175.00      77      M   26               10
# 11        YO  177.00      62      F   20                7
# 12        AI  173.00      61      M   23                2
# 13        PR  164.00      62      F   28                2
# 14        CC  170.00      70      M   29                5
# 15        LO  170.00      74      F   24                3
# 16    Miguel  169.00      67      M   23                2
# 17        LS  165.00      63      M   20               10
# 18        FS    1.69      50      F   20                3
#
#     Location: (0 Village, 1: Town, 2: City, 3: Megacity)
# 0                                                   1
# 1                                                   1
# 2                                                   2
# 3                                                   1
# 4                                                   0
# 5                                                   0
# 6                                                   1
# 7                                                   1
# 8                                                   0
# 9                                                   1
# 10                                                  1
# 11                                                  1
# 12                                                  0
# 13                                                  1
# 14                                                  1
# 15                                                  0
# 16                                                  1
# 17                                                  0
# 18                                                  2

# %%
def correct_height(df):
    for i in range(df.shape[0]) :
        height = df.iloc[i, 1]
        if height < 10:
            df.iloc[i, 1] *= 100
    return
for height in X["Height"]:
    print(height)
correct_height(X)
X
# Out:
# 178.0
# 180.0
# 169.0
# 183.0
# 190.0
# 178.0
# 188.0
# 178.0
# 179.0
# 178.0
# 175.0
# 177.0
# 173.0
# 164.0
# 170.0
# 170.0
# 169.0
# 165.0
# 1.69
#    Pseudonym  Height  Weight Gender  Age  Sporthours/week  \
# 0         CD   178.0      81      M   49                7
# 1         TB   180.0      75      M   22               16
# 2         BL   169.0      53      F   20                0
# 3         KG   183.0      80      M   25                1
# 4         TR   190.0      65      M   25                5
# 5         AR   178.0      82      M   21                4
# 6         BV   188.0      85      M   25                8
# 7         KG   178.0      65      M   24                2
# 8        Bob   179.0      69      M   23                2
# 9         DF   178.0      60      M   37                0
# 10        ZZ   175.0      77      M   26               10
# 11        YO   177.0      62      F   20                7
# 12        AI   173.0      61      M   23                2
# 13        PR   164.0      62      F   28                2
# 14        CC   170.0      70      M   29                5
# 15        LO   170.0      74      F   24                3
# 16    Miguel   169.0      67      M   23                2
# 17        LS   165.0      63      M   20               10
# 18        FS   169.0      50      F   20                3
#
#     Location: (0 Village, 1: Town, 2: City, 3: Megacity)
# 0                                                   1
# 1                                                   1
# 2                                                   2
# 3                                                   1
# 4                                                   0
# 5                                                   0
# 6                                                   1
# 7                                                   1
# 8                                                   0
# 9                                                   1
# 10                                                  1
# 11                                                  1
# 12                                                  0
# 13                                                  1
# 14                                                  1
# 15                                                  0
# 16                                                  1
# 17                                                  0
# 18                                                  2

# %%
Y = X.copy()
Y.at[0, "Pseudonym"] = "haha"
X.mean()
# Out:
# /var/folders/kv/b1gslbxj1sb_wvrlx344hk780000gn/T/ipykernel_89860/3303973669.py:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   X.mean()
# Height                                                  175.421053
# Weight                                                   68.473684
# Age                                                      25.473684
# Sporthours/week                                           4.684211
# Location: (0 Village, 1: Town, 2: City, 3: Megacity)      0.789474
# dtype: float64

# %%
Y
# Out:
#    Pseudonym  Height  Weight Gender  Age  Sporthours/week  \
# 0       haha  178.00      81      M   49                7
# 1         TB  180.00      75      M   22               16
# 2         BL  169.00      53      F   20                0
# 3         KG  183.00      80      M   25                1
# 4         TR  190.00      65      M   25                5
# 5         AR  178.00      82      M   21                4
# 6         BV  188.00      85      M   25                8
# 7         KG  178.00      65      M   24                2
# 8        Bob  179.00      69      M   23                2
# 9         DF  178.00      60      M   37                0
# 10        ZZ  175.00      77      M   26               10
# 11        YO  177.00      62      F   20                7
# 12        AI  173.00      61      M   23                2
# 13        PR  164.00      62      F   28                2
# 14        CC  170.00      70      M   29                5
# 15        LO  170.00      74      F   24                3
# 16    Miguel  169.00      67      M   23                2
# 17        LS  165.00      63      M   20               10
# 18        FS    1.69      50      F   20                3
#
#     Location: (0 Village, 1: Town, 2: City, 3: Megacity)
# 0                                                   1
# 1                                                   1
# 2                                                   2
# 3                                                   1
# 4                                                   0
# 5                                                   0
# 6                                                   1
# 7                                                   1
# 8                                                   0
# 9                                                   1
# 10                                                  1
# 11                                                  1
# 12                                                  0
# 13                                                  1
# 14                                                  1
# 15                                                  0
# 16                                                  1
# 17                                                  0
# 18                                                  2

# %%
X.hist()
# Out:
# array([[<AxesSubplot: title={'center': 'Height'}>,
#         <AxesSubplot: title={'center': 'Weight'}>],
#        [<AxesSubplot: title={'center': 'Age'}>,
#         <AxesSubplot: title={'center': 'Sporthours/week'}>],
#        [<AxesSubplot: title={'center': 'Location: (0 Village, 1: Town, 2: City, 3: Megacity)'}>,
#         <AxesSubplot: >]], dtype=object)

# %%
X.mean()
# Out:
# /var/folders/kv/b1gslbxj1sb_wvrlx344hk780000gn/T/ipykernel_89860/994300582.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   X.mean()
# Height                                                  166.615263
# Weight                                                   68.473684
# Age                                                      25.473684
# Sporthours/week                                           4.684211
# Location: (0 Village, 1: Town, 2: City, 3: Megacity)      0.789474
# dtype: float64

# %%
import numpy as np

x = np.random.uniform(size = 4)
y = np.random.normal(size = 4)

# %%
print(x)
print(y)
# Out:
# [0.06662859 0.92487612 0.50081547 0.70089841]
# [ 0.92158966  0.82075607 -0.58747247  0.69348375]

# %%
h = X["Height"]
w = X["Weight"]
F = X["Gender"]=="F"
M = X["Gender"]=="M"

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(h[F], w[F], 'x')
plt.plot(h[M], w[M], 'o')
