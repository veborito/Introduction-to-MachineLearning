# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import ListedColormap

from sklearn import datasets, neighbors
from sklearn.inspection import DecisionBoundaryDisplay

n_neighbors = 2

# import some data to play with
iris = datasets.load_iris()

# we only take the first two features. We could avoid this ugly
# slicing by using a two-dim dataset
X = iris.data[:, :2]
y = iris.target

# Create color maps
cmap_light = ListedColormap(["orange", "cyan", "cornflowerblue"])
cmap_bold = ["darkorange", "c", "darkblue"]

# %%
## The nearest neighbours classifier

# %%
weights = "uniform"
for n_neighbors in [1, 2, 3, 10, 20, 100, 140, 149, 150]:
    # we create an instance of Neighbours Classifier and fit the data.
    clf = neighbors.KNeighborsClassifier(n_neighbors, weights=weights)
    clf.fit(X, y)

    _, ax = plt.subplots()
    DecisionBoundaryDisplay.from_estimator(
        clf,
        X,
        cmap=cmap_light,
        ax=ax,
        response_method="predict",
        plot_method="pcolormesh",
        xlabel=iris.feature_names[0],
        ylabel=iris.feature_names[1],
        shading="auto",
    )

    # Plot also the training points
    sns.scatterplot(
        x=X[:, 0],
        y=X[:, 1],
        hue=iris.target_names[y],
        palette=cmap_bold,
        alpha=1.0,
        edgecolor="black",
    )
    plt.title(
        "3-Class classification (k = %i, weights = '%s')" % (n_neighbors, weights)
    )

plt.show()

# %% [markdown]
# # sklearn standard methods
#
# Nearly all models in scikit-learn implement the following methods:
#
# - clf.fit(X, y): Fits labelled data
# - clf.predict(X): predict labels given the features
# - clf.predict_proba(X): predict label probabilities given the features (not all models have this method)
#
# ## Measuring model quality
#
#     accuracy_score(y, a)
#
# This returns the average accuracy:
# $$\sum_{t=1}^T I\{y_t = a_t\} / T$$
# where $I\{y_t = a_t\}$ is 1 when the prediction $a_t$ is equal to the label $y_t$, and 0 otherwise.
#
#     log_loss(y, p)
#
# This returns the average log loss
# $$\sum_{t=1}^T \ln p_{t,i} / T$$
# where $p_{t,i} = P(y_t = i | x_t)$ should be a martix of label probabilities for each example $t$ and label $i$.

# %%
# Measuring performance
from sklearn.metrics import accuracy_score, log_loss
import numpy as np
# We now use all features
X = iris.data
y = iris.target
n_neighbors = 1
# we can save the accuracy/loss in those arrays
acc = np.zeros(150)
loss = np.zeros(150)
# go through all values of K
for n_neighbors in range(1, 100):
    ## Fit a k-NN classifier on all the data 
    clf = neighbors.KNeighborsClassifier(n_neighbors, weights=weights)
    clf.fit(X, y)
    ## Calculate the accuracy score, based on the predicted labels 
    y_predicted = clf.predict(X)
    acc[n_neighbors - 1] = accuracy_score(y, y_predicted)
    ## Calculate the log-loss score, based on the label probabilities 
    y_probabilities = clf.predict_proba(X)
    loss[n_neighbors - 1] = log_loss(y, y_probabilities)

# %%
plt.plot(1 - acc)
plt.plot(loss)
plt.legend(["Classification Error", "Log Loss"])

# %%
plt.plot(acc)
plt.plot(-loss)
plt.legend(["Accuracy", "Negative Log Loss"])

# %%
## Training and testing
## Find the best-performing value of k on the training and test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True)
## Loop over n_neighbours
## For each value, calculate (a) the accuracy and (b) the log loss on both the train set and the test set
## What is the best value of k in each case?
# we can save the accuracy/loss in those arrays
acc_train = np.zeros(111)
loss_train = np.zeros(111)
acc_test = np.zeros(38)
loss_test = np.zeros(38)
for n_neighbors in range(1, 112):
    ## Fit a k-NN classifier on all the data 
    clf = neighbors.KNeighborsClassifier(n_neighbors, weights=weights)
    clf.fit(X_train, y_train)
    ## Calculate the accuracy score, based on the predicted labels 
    y_train_predicted = clf.predict(X_train)
    acc_train[n_neighbors - 1] = accuracy_score(y_train, y_train_predicted)
    ## Calculate the log-loss score, based on the label probabilities 
    y_train_probabilities = clf.predict_proba(X_train)
    loss_train[n_neighbors - 1] = log_loss(y_train, y_train_probabilities)
# go through all values of K
for n_neighbors in range(1, 39):
    ## Fit a k-NN classifier on all the data 
    clf = neighbors.KNeighborsClassifier(n_neighbors, weights=weights)
    clf.fit(X_test, y_test)
    ## Calculate the accuracy score, based on the predicted labels 
    y_test_predicted = clf.predict(X_test)
    acc_test[n_neighbors - 1] = accuracy_score(y_test, y_test_predicted)
    ## Calculate the log-loss score, based on the label probabilities 
    y_test_probabilities = clf.predict_proba(X_test)
    loss_test[n_neighbors - 1] = log_loss(y_test, y_test_probabilities)    
plt.plot(1 - acc_train)
plt.plot(loss_train)
plt.legend(["Classification Error Train" , "Log Loss Train"])

# %%
plt.plot(1 - acc_test)
plt.plot(loss_test)
plt.legend(["Classification Error Test" , "Log Loss Test"])

# %%
## Does scaling help?
## Do we get better performance if we scale the data? 
## Plot the results again for increasing k. Is the optimal k different?
from sklearn.preprocessing import StandardScaler
object = StandardScaler()
X_train_scale = object.fit_transform(X_train)
X_test_scale = object.fit_transform(X_test)
acc_train_scale = np.zeros(111)
loss_train_scale = np.zeros(111)
acc_test_scale = np.zeros(38)
loss_test_scale = np.zeros(38)
for n_neighbors in range(1, 112):
    ## Fit a k-NN classifier on all the data 
    clf = neighbors.KNeighborsClassifier(n_neighbors, weights=weights)
    clf.fit(X_train_scale, y_train)
    ## Calculate the accuracy score, based on the predicted labels 
    y_train_predicted = clf.predict(X_train_scale)
    acc_train_scale[n_neighbors - 1] = accuracy_score(y_train, y_train_predicted)
    ## Calculate the log-loss score, based on the label probabilities 
    y_train_probabilities = clf.predict_proba(X_train_scale)
    loss_train_scale[n_neighbors - 1] = log_loss(y_train, y_train_probabilities)
# go through all values of K
for n_neighbors in range(1, 39):
    ## Fit a k-NN classifier on all the data 
    clf = neighbors.KNeighborsClassifier(n_neighbors, weights=weights)
    clf.fit(X_test_scale, y_test)
    ## Calculate the accuracy score, based on the predicted labels 
    y_test_predicted = clf.predict(X_test_scale)
    acc_test_scale[n_neighbors - 1] = accuracy_score(y_test, y_test_predicted)
    ## Calculate the log-loss score, based on the label probabilities 
    y_test_probabilities = clf.predict_proba(X_test_scale)
    loss_test_scale[n_neighbors - 1] = log_loss(y_test, y_test_probabilities)    

plt.plot(1 - acc_train_scale)
plt.plot(loss_train_scale)
plt.legend(["Classification Error Train" , "Log Loss Train"])

# %%
plt.plot(1 - acc_test_scale)
plt.plot(loss_test_scale)
plt.legend(["Classification Error Test" , "Log Loss Test"])

# %% [markdown]
# ### Question 2
# We see that scaling helps decreasing error with higher values of k.
# The optimal k seems still to be 1.

# %% [markdown]
# ## Measuring model quality
#
# Here you need to implement the function
#
#     utility_score(y, a, U)
#
# which returns a score according to the following formula:
# $$\sum_{t=1}^T U(a_t, y_t) / T$$.
#
# Here `y`, `a` are arrays, with `y[t]` being $y_t$ and `a[t]` being $a_t$.
# `U` is a function returning a real number, and is implemented below as `utility_function`
#
# |  U  | y=0 | y=1 | y=2 |
# | --- | --- | --- | --- |
# | a=0 |  0  |  1  | -10 |
# | a=1 | -1  |  1  |  -1 |
# | a=2 | -2  |  -2 |  2  |

# %%
def utility_function(a, y):
    # implementation hint: Define a matrix U with the correct entries and simply return U[a,y] 
    U = np.array([
        [0, 1, -10],
        [-1, 1, -1],
        [-2, -2, 2]])
    total = 0
    T = len(a)
    for i in range(T):
        total += U[a[i],y[i]]
    return total/T

# %%
# After you implement the function, use it to evaluate your classification model in training and and testing.
# Plot the results for different n_neigbhors
utility_train = np.zeros(111)
utility_test = np.zeros(38)

for n_neighbors in range(1, 112):
    ## Fit a k-NN classifier on all the data 
    clf = neighbors.KNeighborsClassifier(n_neighbors, weights=weights)
    clf.fit(X_train, y_train)
    y_train_predicted = clf.predict(X_train)
    utility_train[n_neighbors - 1] = utility_function(y_train_predicted, y_train)
for n_neighbors in range(1, 39):
    ## Fit a k-NN classifier on all the data 
    clf = neighbors.KNeighborsClassifier(n_neighbors, weights=weights)
    clf.fit(X_test, y_test)
    y_test_predicted = clf.predict(X_test)
    utility_test[n_neighbors - 1] = utility_function(y_test_predicted, y_test)

# %%
plt.plot(utility_train)
plt.legend(["Utility function for Train data"])

# %%
plt.plot(utility_test)
plt.legend(["Utility function for Test data"])

# %%
# How can you better use your kNN model, in order to obtain better performance under the utility_score measure? Only explain in words, no need to implement this, it will be done in class.

# %% [markdown]
# ### Question 4
# Maybe, we can transform our data to fit only extreme values of the dataset so we have a better frontier delimitation and less prediction error with higher values of k. Simple
